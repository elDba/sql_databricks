# %%
# %sql
CREATE CATALOG IF NOT EXISTS kiosco

# %%
# %sql
CREATE TABLE IF NOT EXISTS kiosco.default.productos (
  id int,
  nombre string,
  categoria int
)

# %%
# %sql
INSERT INTO kiosco.default.productos VALUES
(1, 'Agua Mineral', 1),
(2, 'Gaseosa', 1),
(3, 'Cerveza', 2),
(4, 'Vino', 2),
(5, 'Galletitas', 3),
(6, 'Alfajor', 3)

# %%
# %sql
select * from default.productos
